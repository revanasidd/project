# %% [markdown]
# # Assignment 3
#  ## `1st Problem & Soultion`
# > output be like this
#
#     BBBBB
#     BBBB
#     BBB
#     BB
#     B

# %%
for i in range(5,0,-1):
    print(i*'B')
# Out:
# BBBBB
# BBBB
# BBB
# BB
# B

# %% [markdown]
# ## `2nd Problem & Soultion`
# > output be like this
#
#        B
#       BB
#      BBB
#     BBBB

# %%
for i in range(5,-1,-1):
    print((i*' ') + (4-i)*'B')
# Out:
#
#
#    B
#   BB
#  BBB
# BBBB

# %% [markdown]
# ## `3rd Problem & Soultion`
# > output be like this
#
#       1
#       B2
#       BB3
#       BBB4

# %%
n = int(input('Enter Number :'))
for i in range(1,n):
    if i == 1:
        print((i),end='\n')
    print((i)*'B'+str(i+1))
# Out:
# Enter Number :4
# 1
# B2
# BB3
# BBB4

# %% [markdown]
# ## `4th Problem & Soultion`
# > output be like this
#
#       B
#       1BB
#       2BBB
#       3BBBB

# %%
n = int(input('Enter Number :'))
for i in range(1,n):
    if i == 1:
        print(("B"))
    print(str(i)+(i+1)*'B')
# Out:
# Enter Number :4
# B
# 1BB
# 2BBB
# 3BBBB

# %% [markdown]
# ## `5th Problem & Soultion`
# > output be like this
#
#       BB
#       BBBB
#       BBBBBB

# %%
n = int(input('Enter Number :'))
for i in range(1,n,2):
    print((i+1)*'B')
# Out:
# Enter Number :7
# BB
# BBBB
# BBBBBB

# %% [markdown]
# ## `6th Problem & Soultion`
# > output be like this
#
#       1
#       23
#       456
#       78910

# %%
n = int(input('Enter Number :'))
num = 1
for i in range(1,n):
    for n in range(1,i):
        print(num,end='')
        num=num+1
    print('\r')
# Out:
# Enter Number :5
#
# 1
# 23
# 456

# %%
for i in range(4):
    if i == 3:
        break
    print(i)
print('end')
# Out:
# 0
# 1
# 2
# end

# %%
for i in range(5):
    if i == 4:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(1,11):
    print(i,end='')
# Out:
# 12345678910
